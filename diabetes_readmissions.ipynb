# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
plt.style.use('seaborn-deep')

# %%
filepathname = 'c:\\Users\\micha\\Documents\\GitHub\\diabetes_readmissions\\diabetes.csv'
df = pd.read_csv(filepathname, header=0,)
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %% [markdown]
# # Start of Section on Functions

# %%
# Helper function that will show normalized value counts for features
def show_column_values():
    for feature in df.columns:
        print("Name of Feature:", feature)
        print(df[feature].value_counts(normalize=True))
        print("\n")

# %%
# Helper function to generate specific univariate plots
def create_plots(myXaxis,myYaxis,myXlabel,myYlabel,myTitle,myPlot,fsize=7):
    
    fig, notch_ax = plt.subplots(1, 1, figsize = (fsize,fsize))
    if myPlot == "Boxplot":
        sns.boxplot(ax = notch_ax,x = myXaxis, y = myYaxis, data = df,notch=True)
    elif myPlot == "Barplot":
        df_sub = df.groupby([myXaxis],as_index=False)[[myYaxis]].count()
        sns.barplot(ax = notch_ax, data = df_sub, x = myXaxis, y = myYaxis,edgecolor='black')
    elif myPlot == "Heatmap":
        sns.heatmap(ax = notch_ax, data=df.corr(),annot=True)
    elif myPlot == "Histplot":
        sns.histplot(data=df, x = myXaxis)

    plt.title(myTitle)
    plt.xlabel(myXlabel)
    plt.ylabel(myYlabel)

    # Heatmap does not need to have y axis label formatted
    if myPlot != "Heatmap":
        plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))
    plt.show()

# %% [markdown]
# # End of Section on Functions

# %%
df.shape
# Out:
# (101766, 50)

# %%
tips = sns.load_dataset("tips")

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df.nunique()
# Out:
# encounter_id                101766
# patient_nbr                  71518
# race                             6
# gender                           3
# age                             10
# weight                          10
# admission_type_id                8
# discharge_disposition_id        26
# admission_source_id             17
# time_in_hospital                14
# payer_code                      18
# medical_specialty               73
# num_lab_procedures             118
# num_procedures                   7
# num_medications                 75
# number_outpatient               39
# number_emergency                33
# number_inpatient                21
# diag_1                         717
# diag_2                         749
# diag_3                         790
# number_diagnoses                16
# max_glu_serum                    4
# A1Cresult                        4
# metformin                        4
# repaglinide                      4
# nateglinide                      4
# chlorpropamide                   4
# glimepiride                      4
# acetohexamide                    2
# glipizide                        4
# glyburide                        4
# tolbutamide                      2
# pioglitazone                     4
# rosiglitazone                    4
# acarbose                         4
# miglitol                         4
# troglitazone                     2
# tolazamide                       3
# examide                          1
# citoglipton                      1
# insulin                          4
# glyburide-metformin              4
# glipizide-metformin              2
# glimepiride-pioglitazone         2
# metformin-rosiglitazone          2
# metformin-pioglitazone           2
# change                           2
# diabetesMed                      2
# readmitted                       3
# dtype: int64

# %%
# Inspect the features that need to be deleted
show_column_values()
# Out:
# Name of Feature: encounter_id
# 2278392      0.00001
# 190792044    0.00001
# 190790070    0.00001
# 190789722    0.00001
# 190786806    0.00001
#               ...
# 106665324    0.00001
# 106657776    0.00001
# 106644876    0.00001
# 106644474    0.00001
# 443867222    0.00001
# Name: encounter_id, Length: 101766, dtype: float64
#
#
# Name of Feature: patient_nbr
# 88785891     0.000393
# 43140906     0.000275
# 1660293      0.000226
# 88227540     0.000226
# 23199021     0.000226
#                ...
# 11005362     0.000010
# 98252496     0.000010
# 1019673      0.000010
# 13396320     0.000010
# 175429310    0.000010
# Name: patient_nbr, Length: 71518, dtype: float64
#
#
# Name of Feature: race
# Caucasian          0.747784
# AfricanAmerican    0.188766
# ?                  0.022336
# Hispanic           0.020017
# Other              0.014799
# Asian              0.006299
# Name: race, dtype: float64
#
#
# Name of Feature: gender
# Female             0.537586
# Male               0.462384
# Unknown/Invalid    0.000029
# Name: gender, dtype: float64
#
#
# Name of Feature: age
# [70-80)     0.256156
# [60-70)     0.220928
# [50-60)     0.169565
# [80-90)     0.168986
# [40-50)     0.095169
# [30-40)     0.037095
# [90-100)    0.027445
# [20-30)     0.016282
# [10-20)     0.006790
# [0-10)      0.001582
# Name: age, dtype: float64
#
#
# Name of Feature: weight
# ?            0.968585
# [75-100)     0.013128
# [50-75)      0.008814
# [100-125)    0.006142
# [125-150)    0.001425
# [25-50)      0.000953
# [0-25)       0.000472
# [150-175)    0.000344
# [175-200)    0.000108
# >200         0.000029
# Name: weight, dtype: float64
#
#
# Name of Feature: admission_type_id
# 1    0.530531
# 3    0.185416
# 2    0.181593
# 6    0.051992
# 5    0.047020
# 8    0.003144
# 7    0.000206
# 4    0.000098
# Name: admission_type_id, dtype: float64
#
#
# Name of Feature: discharge_disposition_id
# 1     0.591887
# 3     0.137118
# 6     0.126781
# 18    0.036269
# 2     0.020911
# 22    0.019584
# 11    0.016135
# 5     0.011635
# 25    0.009718
# 4     0.008009
# 7     0.006122
# 23    0.004049
# 13    0.003921
# 14    0.003655
# 28    0.001366
# 8     0.001061
# 15    0.000619
# 24    0.000472
# 9     0.000206
# 17    0.000138
# 16    0.000108
# 19    0.000079
# 10    0.000059
# 27    0.000049
# 12    0.000029
# 20    0.000020
# Name: discharge_disposition_id, dtype: float64
#
#
# Name of Feature: admission_source_id
# 7     0.564963
# 1     0.290519
# 17    0.066633
# 4     0.031317
# 6     0.022247
# 2     0.010848
# 5     0.008402
# 3     0.001838
# 20    0.001582
# 9     0.001228
# 8     0.000157
# 22    0.000118
# 10    0.000079
# 14    0.000020
# 11    0.000020
# 25    0.000020
# 13    0.000010
# Name: admission_source_id, dtype: float64
#
#
# Name of Feature: time_in_hospital
# 3     0.174479
# 2     0.169251
# 1     0.139614
# 4     0.136824
# 5     0.097931
# 6     0.074082
# 7     0.057573
# 8     0.043148
# 9     0.029499
# 10    0.023014
# 11    0.018228
# 12    0.014229
# 13    0.011890
# 14    0.010239
# Name: time_in_hospital, dtype: float64
#
#
# Name of Feature: payer_code
# ?     0.395574
# MC    0.318761
# HM    0.061651
# SP    0.049201
# BC    0.045742
# MD    0.034707
# CP    0.024890
# UN    0.024055
# CM    0.019034
# OG    0.010151
# PO    0.005817
# DM    0.005395
# CH    0.001435
# WC    0.001327
# OT    0.000934
# MP    0.000776
# SI    0.000540
# FR    0.000010
# Name: payer_code, dtype: float64
#
#
# Name of Feature: medical_specialty
# ?                                0.490822
# InternalMedicine                 0.143810
# Emergency/Trauma                 0.074337
# Family/GeneralPractice           0.073109
# Cardiology                       0.052591
#                                    ...
# SportsMedicine                   0.000010
# Speech                           0.000010
# Perinatology                     0.000010
# Neurophysiology                  0.000010
# Pediatrics-InfectiousDiseases    0.000010
# Name: medical_specialty, Length: 73, dtype: float64
#
#
# Name of Feature: num_lab_procedures
# 1      0.031523
# 43     0.027553
# 44     0.024527
# 45     0.023348
# 38     0.021746
#          ...
# 120    0.000010
# 132    0.000010
# 121    0.000010
# 126    0.000010
# 118    0.000010
# Name: num_lab_procedures, Length: 118, dtype: float64
#
#
# Name of Feature: num_procedures
# 0    0.458424
# 1    0.203821
# 2    0.124963
# 3    0.092791
# 6    0.048680
# 4    0.041075
# 5    0.030246
# Name: num_procedures, dtype: float64
#
#
# Name of Feature: num_medications
# 13    0.059804
# 12    0.058998
# 11    0.056944
# 15    0.056915
# 14    0.056080
#         ...
# 70    0.000020
# 75    0.000020
# 81    0.000010
# 79    0.000010
# 74    0.000010
# Name: num_medications, Length: 75, dtype: float64
#
#
# Name of Feature: number_outpatient
# 0     0.835515
# 1     0.083987
# 2     0.035316
# 3     0.020066
# 4     0.010799
# 5     0.005238
# 6     0.002977
# 7     0.001523
# 8     0.000963
# 9     0.000816
# 10    0.000560
# 11    0.000413
# 13    0.000305
# 12    0.000295
# 14    0.000275
# 15    0.000197
# 16    0.000147
# 17    0.000079
# 21    0.000069
# 20    0.000069
# 18    0.000049
# 22    0.000049
# 19    0.000029
# 27    0.000029
# 24    0.000029
# 26    0.000020
# 23    0.000020
# 25    0.000020
# 33    0.000020
# 35    0.000020
# 36    0.000020
# 29    0.000020
# 34    0.000010
# 39    0.000010
# 42    0.000010
# 28    0.000010
# 37    0.000010
# 38    0.000010
# 40    0.000010
# Name: number_outpatient, dtype: float64
#
#
# Name of Feature: number_emergency
# 0     0.888145
# 1     0.075438
# 2     0.020066
# 3     0.007124
# 4     0.003675
# 5     0.001887
# 6     0.000924
# 7     0.000717
# 8     0.000491
# 10    0.000334
# 9     0.000324
# 11    0.000226
# 13    0.000118
# 12    0.000098
# 22    0.000059
# 16    0.000049
# 18    0.000049
# 19    0.000039
# 20    0.000039
# 15    0.000029
# 14    0.000029
# 25    0.000020
# 21    0.000020
# 28    0.000010
# 42    0.000010
# 46    0.000010
# 76    0.000010
# 37    0.000010
# 64    0.000010
# 63    0.000010
# 54    0.000010
# 24    0.000010
# 29    0.000010
# Name: number_emergency, dtype: float64
#
#
# Name of Feature: number_inpatient
# 0     0.664564
# 1     0.191822
# 2     0.074347
# 3     0.033518
# 4     0.015939
# 5     0.007979
# 6     0.004717
# 7     0.002633
# 8     0.001484
# 9     0.001091
# 10    0.000599
# 11    0.000481
# 12    0.000334
# 13    0.000197
# 14    0.000098
# 15    0.000088
# 16    0.000059
# 19    0.000020
# 17    0.000010
# 21    0.000010
# 18    0.000010
# Name: number_inpatient, dtype: float64
#
#
# Name of Feature: diag_1
# 428    0.067429
# 414    0.064668
# 786    0.039463
# 410    0.035513
# 486    0.034471
#          ...
# 373    0.000010
# 314    0.000010
# 684    0.000010
# 217    0.000010
# V51    0.000010
# Name: diag_1, Length: 717, dtype: float64
#
#
# Name of Feature: diag_2
# 276     0.066348
# 428     0.065464
# 250     0.059656
# 427     0.049486
# 401     0.036712
#           ...
# E918    0.000010
# 46      0.000010
# V13     0.000010
# E850    0.000010
# 927     0.000010
# Name: diag_2, Length: 749, dtype: float64
#
#
# Name of Feature: diag_3
# 250     0.113545
# 401     0.081452
# 276     0.050852
# 428     0.044976
# 427     0.038864
#           ...
# 657     0.000010
# 684     0.000010
# 603     0.000010
# E826    0.000010
# 971     0.000010
# Name: diag_3, Length: 790, dtype: float64
#
#
# Name of Feature: number_diagnoses
# 9     0.486155
# 5     0.111953
# 8     0.104318
# 7     0.102126
# 6     0.099847
# 4     0.054409
# 3     0.027858
# 2     0.010052
# 1     0.002152
# 16    0.000442
# 10    0.000167
# 13    0.000157
# 11    0.000108
# 15    0.000098
# 12    0.000088
# 14    0.000069
# Name: number_diagnoses, dtype: float64
#
#
# Name of Feature: max_glu_serum
# None    0.947468
# Norm    0.025519
# >200    0.014592
# >300    0.012421
# Name: max_glu_serum, dtype: float64
#
#
# Name of Feature: A1Cresult
# None    0.832773
# >8      0.080734
# Norm    0.049034
# >7      0.037458
# Name: A1Cresult, dtype: float64
#
#
# Name of Feature: metformin
# No        0.803589
# Steady    0.180276
# Up        0.010485
# Down      0.005650
# Name: metformin, dtype: float64
#
#
# Name of Feature: repaglinide
# No        0.984877
# Steady    0.013600
# Up        0.001081
# Down      0.000442
# Name: repaglinide, dtype: float64
#
#
# Name of Feature: nateglinide
# No        0.993092
# Steady    0.006564
# Up        0.000236
# Down      0.000108
# Name: nateglinide, dtype: float64
#
#
# Name of Feature: chlorpropamide
# No        0.999155
# Steady    0.000776
# Up        0.000059
# Down      0.000010
# Name: chlorpropamide, dtype: float64
#
#
# Name of Feature: glimepiride
# No        0.948991
# Steady    0.045890
# Up        0.003213
# Down      0.001906
# Name: glimepiride, dtype: float64
#
#
# Name of Feature: acetohexamide
# No        0.99999
# Steady    0.00001
# Name: acetohexamide, dtype: float64
#
#
# Name of Feature: glipizide
# No        0.875341
# Steady    0.111589
# Up        0.007566
# Down      0.005503
# Name: glipizide, dtype: float64
#
#
# Name of Feature: glyburide
# No        0.895348
# Steady    0.091131
# Up        0.007979
# Down      0.005542
# Name: glyburide, dtype: float64
#
#
# Name of Feature: tolbutamide
# No        0.999774
# Steady    0.000226
# Name: tolbutamide, dtype: float64
#
#
# Name of Feature: pioglitazone
# No        0.927992
# Steady    0.068549
# Up        0.002299
# Down      0.001160
# Name: pioglitazone, dtype: float64
#
#
# Name of Feature: rosiglitazone
# No        0.937455
# Steady    0.059941
# Up        0.001749
# Down      0.000855
# Name: rosiglitazone, dtype: float64
#
#
# Name of Feature: acarbose
# No        0.996973
# Steady    0.002899
# Up        0.000098
# Down      0.000029
# Name: acarbose, dtype: float64
#
#
# Name of Feature: miglitol
# No        0.999627
# Steady    0.000305
# Down      0.000049
# Up        0.000020
# Name: miglitol, dtype: float64
#
#
# Name of Feature: troglitazone
# No        0.999971
# Steady    0.000029
# Name: troglitazone, dtype: float64
#
#
# Name of Feature: tolazamide
# No        0.999617
# Steady    0.000373
# Up        0.000010
# Name: tolazamide, dtype: float64
#
#
# Name of Feature: examide
# No    1.0
# Name: examide, dtype: float64
#
#
# Name of Feature: citoglipton
# No    1.0
# Name: citoglipton, dtype: float64
#
#
# Name of Feature: insulin
# No        0.465607
# Steady    0.303137
# Down      0.120060
# Up        0.111196
# Name: insulin, dtype: float64
#
#
# Name of Feature: glyburide-metformin
# No        0.993063
# Steady    0.006800
# Up        0.000079
# Down      0.000059
# Name: glyburide-metformin, dtype: float64
#
#
# Name of Feature: glipizide-metformin
# No        0.999872
# Steady    0.000128
# Name: glipizide-metformin, dtype: float64
#
#
# Name of Feature: glimepiride-pioglitazone
# No        0.99999
# Steady    0.00001
# Name: glimepiride-pioglitazone, dtype: float64
#
#
# Name of Feature: metformin-rosiglitazone
# No        0.99998
# Steady    0.00002
# Name: metformin-rosiglitazone, dtype: float64
#
#
# Name of Feature: metformin-pioglitazone
# No        0.99999
# Steady    0.00001
# Name: metformin-pioglitazone, dtype: float64
#
#
# Name of Feature: change
# No    0.538048
# Ch    0.461952
# Name: change, dtype: float64
#
#
# Name of Feature: diabetesMed
# Yes    0.770031
# No     0.229969
# Name: diabetesMed, dtype: float64
#
#
# Name of Feature: readmitted
# NO     0.539119
# >30    0.349282
# <30    0.111599
# Name: readmitted, dtype: float64

# %% [markdown]
# The features_excluded list below are features to be dropped.
# The reason for excluding each feature are:
# 1. encounter_id: Is an autonumber for each row, a counter for rows in the dataset, does not drive what is happening to the target: readmitted
# 2. weight: Over 97% of the records are missing the weight value
# 3. payer_code: Over 40% of the records are missing the payor code, payers don't make the decision on when to admit
# 4. medical_specialty: Over 49% of the records are missing the specialty value, specialty is not making the decision to admit. It is based on the clinical findings which are determined from the assessment of the health team
# 5. diag_1, diag_2, and diag_3: Based on an average of 740 diagnosis codes listed for each column it would be impractical to one hot encode each column into 2,100 columns. The next feature of number_diagnoses is more valuable for seeing the impact of co-morbidity; the presence of two or more diseases
# 6. examide and citoglipton: Were not listed on any encounter as being taken

# %%
features_excluded = ['encounter_id','weight','payer_code','medical_specialty','diag_1','diag_2','diag_3','examide','citoglipton']

# %%
# Dropping columns
df.drop(columns=features_excluded,inplace=True)

# %%
# Inspect the features for rows that need to be deleted
# An imputer is not going to appropriate for this rows
show_column_values()
# Out:
# Name of Feature: patient_nbr
# 88785891     0.000393
# 43140906     0.000275
# 1660293      0.000226
# 88227540     0.000226
# 23199021     0.000226
#                ...
# 11005362     0.000010
# 98252496     0.000010
# 1019673      0.000010
# 13396320     0.000010
# 175429310    0.000010
# Name: patient_nbr, Length: 71518, dtype: float64
#
#
# Name of Feature: race
# Caucasian          0.747784
# AfricanAmerican    0.188766
# ?                  0.022336
# Hispanic           0.020017
# Other              0.014799
# Asian              0.006299
# Name: race, dtype: float64
#
#
# Name of Feature: gender
# Female             0.537586
# Male               0.462384
# Unknown/Invalid    0.000029
# Name: gender, dtype: float64
#
#
# Name of Feature: age
# [70-80)     0.256156
# [60-70)     0.220928
# [50-60)     0.169565
# [80-90)     0.168986
# [40-50)     0.095169
# [30-40)     0.037095
# [90-100)    0.027445
# [20-30)     0.016282
# [10-20)     0.006790
# [0-10)      0.001582
# Name: age, dtype: float64
#
#
# Name of Feature: admission_type_id
# 1    0.530531
# 3    0.185416
# 2    0.181593
# 6    0.051992
# 5    0.047020
# 8    0.003144
# 7    0.000206
# 4    0.000098
# Name: admission_type_id, dtype: float64
#
#
# Name of Feature: discharge_disposition_id
# 1     0.591887
# 3     0.137118
# 6     0.126781
# 18    0.036269
# 2     0.020911
# 22    0.019584
# 11    0.016135
# 5     0.011635
# 25    0.009718
# 4     0.008009
# 7     0.006122
# 23    0.004049
# 13    0.003921
# 14    0.003655
# 28    0.001366
# 8     0.001061
# 15    0.000619
# 24    0.000472
# 9     0.000206
# 17    0.000138
# 16    0.000108
# 19    0.000079
# 10    0.000059
# 27    0.000049
# 12    0.000029
# 20    0.000020
# Name: discharge_disposition_id, dtype: float64
#
#
# Name of Feature: admission_source_id
# 7     0.564963
# 1     0.290519
# 17    0.066633
# 4     0.031317
# 6     0.022247
# 2     0.010848
# 5     0.008402
# 3     0.001838
# 20    0.001582
# 9     0.001228
# 8     0.000157
# 22    0.000118
# 10    0.000079
# 14    0.000020
# 11    0.000020
# 25    0.000020
# 13    0.000010
# Name: admission_source_id, dtype: float64
#
#
# Name of Feature: time_in_hospital
# 3     0.174479
# 2     0.169251
# 1     0.139614
# 4     0.136824
# 5     0.097931
# 6     0.074082
# 7     0.057573
# 8     0.043148
# 9     0.029499
# 10    0.023014
# 11    0.018228
# 12    0.014229
# 13    0.011890
# 14    0.010239
# Name: time_in_hospital, dtype: float64
#
#
# Name of Feature: num_lab_procedures
# 1      0.031523
# 43     0.027553
# 44     0.024527
# 45     0.023348
# 38     0.021746
#          ...
# 120    0.000010
# 132    0.000010
# 121    0.000010
# 126    0.000010
# 118    0.000010
# Name: num_lab_procedures, Length: 118, dtype: float64
#
#
# Name of Feature: num_procedures
# 0    0.458424
# 1    0.203821
# 2    0.124963
# 3    0.092791
# 6    0.048680
# 4    0.041075
# 5    0.030246
# Name: num_procedures, dtype: float64
#
#
# Name of Feature: num_medications
# 13    0.059804
# 12    0.058998
# 11    0.056944
# 15    0.056915
# 14    0.056080
#         ...
# 70    0.000020
# 75    0.000020
# 81    0.000010
# 79    0.000010
# 74    0.000010
# Name: num_medications, Length: 75, dtype: float64
#
#
# Name of Feature: number_outpatient
# 0     0.835515
# 1     0.083987
# 2     0.035316
# 3     0.020066
# 4     0.010799
# 5     0.005238
# 6     0.002977
# 7     0.001523
# 8     0.000963
# 9     0.000816
# 10    0.000560
# 11    0.000413
# 13    0.000305
# 12    0.000295
# 14    0.000275
# 15    0.000197
# 16    0.000147
# 17    0.000079
# 21    0.000069
# 20    0.000069
# 18    0.000049
# 22    0.000049
# 19    0.000029
# 27    0.000029
# 24    0.000029
# 26    0.000020
# 23    0.000020
# 25    0.000020
# 33    0.000020
# 35    0.000020
# 36    0.000020
# 29    0.000020
# 34    0.000010
# 39    0.000010
# 42    0.000010
# 28    0.000010
# 37    0.000010
# 38    0.000010
# 40    0.000010
# Name: number_outpatient, dtype: float64
#
#
# Name of Feature: number_emergency
# 0     0.888145
# 1     0.075438
# 2     0.020066
# 3     0.007124
# 4     0.003675
# 5     0.001887
# 6     0.000924
# 7     0.000717
# 8     0.000491
# 10    0.000334
# 9     0.000324
# 11    0.000226
# 13    0.000118
# 12    0.000098
# 22    0.000059
# 16    0.000049
# 18    0.000049
# 19    0.000039
# 20    0.000039
# 15    0.000029
# 14    0.000029
# 25    0.000020
# 21    0.000020
# 28    0.000010
# 42    0.000010
# 46    0.000010
# 76    0.000010
# 37    0.000010
# 64    0.000010
# 63    0.000010
# 54    0.000010
# 24    0.000010
# 29    0.000010
# Name: number_emergency, dtype: float64
#
#
# Name of Feature: number_inpatient
# 0     0.664564
# 1     0.191822
# 2     0.074347
# 3     0.033518
# 4     0.015939
# 5     0.007979
# 6     0.004717
# 7     0.002633
# 8     0.001484
# 9     0.001091
# 10    0.000599
# 11    0.000481
# 12    0.000334
# 13    0.000197
# 14    0.000098
# 15    0.000088
# 16    0.000059
# 19    0.000020
# 17    0.000010
# 21    0.000010
# 18    0.000010
# Name: number_inpatient, dtype: float64
#
#
# Name of Feature: number_diagnoses
# 9     0.486155
# 5     0.111953
# 8     0.104318
# 7     0.102126
# 6     0.099847
# 4     0.054409
# 3     0.027858
# 2     0.010052
# 1     0.002152
# 16    0.000442
# 10    0.000167
# 13    0.000157
# 11    0.000108
# 15    0.000098
# 12    0.000088
# 14    0.000069
# Name: number_diagnoses, dtype: float64
#
#
# Name of Feature: max_glu_serum
# None    0.947468
# Norm    0.025519
# >200    0.014592
# >300    0.012421
# Name: max_glu_serum, dtype: float64
#
#
# Name of Feature: A1Cresult
# None    0.832773
# >8      0.080734
# Norm    0.049034
# >7      0.037458
# Name: A1Cresult, dtype: float64
#
#
# Name of Feature: metformin
# No        0.803589
# Steady    0.180276
# Up        0.010485
# Down      0.005650
# Name: metformin, dtype: float64
#
#
# Name of Feature: repaglinide
# No        0.984877
# Steady    0.013600
# Up        0.001081
# Down      0.000442
# Name: repaglinide, dtype: float64
#
#
# Name of Feature: nateglinide
# No        0.993092
# Steady    0.006564
# Up        0.000236
# Down      0.000108
# Name: nateglinide, dtype: float64
#
#
# Name of Feature: chlorpropamide
# No        0.999155
# Steady    0.000776
# Up        0.000059
# Down      0.000010
# Name: chlorpropamide, dtype: float64
#
#
# Name of Feature: glimepiride
# No        0.948991
# Steady    0.045890
# Up        0.003213
# Down      0.001906
# Name: glimepiride, dtype: float64
#
#
# Name of Feature: acetohexamide
# No        0.99999
# Steady    0.00001
# Name: acetohexamide, dtype: float64
#
#
# Name of Feature: glipizide
# No        0.875341
# Steady    0.111589
# Up        0.007566
# Down      0.005503
# Name: glipizide, dtype: float64
#
#
# Name of Feature: glyburide
# No        0.895348
# Steady    0.091131
# Up        0.007979
# Down      0.005542
# Name: glyburide, dtype: float64
#
#
# Name of Feature: tolbutamide
# No        0.999774
# Steady    0.000226
# Name: tolbutamide, dtype: float64
#
#
# Name of Feature: pioglitazone
# No        0.927992
# Steady    0.068549
# Up        0.002299
# Down      0.001160
# Name: pioglitazone, dtype: float64
#
#
# Name of Feature: rosiglitazone
# No        0.937455
# Steady    0.059941
# Up        0.001749
# Down      0.000855
# Name: rosiglitazone, dtype: float64
#
#
# Name of Feature: acarbose
# No        0.996973
# Steady    0.002899
# Up        0.000098
# Down      0.000029
# Name: acarbose, dtype: float64
#
#
# Name of Feature: miglitol
# No        0.999627
# Steady    0.000305
# Down      0.000049
# Up        0.000020
# Name: miglitol, dtype: float64
#
#
# Name of Feature: troglitazone
# No        0.999971
# Steady    0.000029
# Name: troglitazone, dtype: float64
#
#
# Name of Feature: tolazamide
# No        0.999617
# Steady    0.000373
# Up        0.000010
# Name: tolazamide, dtype: float64
#
#
# Name of Feature: insulin
# No        0.465607
# Steady    0.303137
# Down      0.120060
# Up        0.111196
# Name: insulin, dtype: float64
#
#
# Name of Feature: glyburide-metformin
# No        0.993063
# Steady    0.006800
# Up        0.000079
# Down      0.000059
# Name: glyburide-metformin, dtype: float64
#
#
# Name of Feature: glipizide-metformin
# No        0.999872
# Steady    0.000128
# Name: glipizide-metformin, dtype: float64
#
#
# Name of Feature: glimepiride-pioglitazone
# No        0.99999
# Steady    0.00001
# Name: glimepiride-pioglitazone, dtype: float64
#
#
# Name of Feature: metformin-rosiglitazone
# No        0.99998
# Steady    0.00002
# Name: metformin-rosiglitazone, dtype: float64
#
#
# Name of Feature: metformin-pioglitazone
# No        0.99999
# Steady    0.00001
# Name: metformin-pioglitazone, dtype: float64
#
#
# Name of Feature: change
# No    0.538048
# Ch    0.461952
# Name: change, dtype: float64
#
#
# Name of Feature: diabetesMed
# Yes    0.770031
# No     0.229969
# Name: diabetesMed, dtype: float64
#
#
# Name of Feature: readmitted
# NO     0.539119
# >30    0.349282
# <30    0.111599
# Name: readmitted, dtype: float64

# %%
# Drop rows with missing values
# Listing features with rows missing values
num_rows = 0
missing_values = ['race']
for feature in missing_values:
    df_filter = df[df[feature] == '?']
    num_rows += df_filter.shape[0]
    print("Number of rows to be dropped: {:,.0f} with value of '?' in feature {}".format(df_filter.shape[0],feature))
    df.drop(df_filter.index, inplace = True)
print("Total number of rows deleted: {:,.0f}".format(num_rows))
print("Number of rows in dataframe after rows are deleted: {:,.0f}".format(df.shape[0]))
# Out:
# Number of rows to be dropped: 2,273 with value of '?' in feature race
# Total number of rows deleted: 2,273
# Number of rows in dataframe after rows are deleted: 99,493

# %%
# Check for the existence of duplicate records
df.duplicated().sum()
# Out:
# 0

# %%
show_column_values()
# Out:
# Name of Feature: patient_nbr
# 88785891     0.000402
# 43140906     0.000281
# 88227540     0.000231
# 23199021     0.000231
# 1660293      0.000231
#                ...
# 25768926     0.000010
# 9788337      0.000010
# 29974896     0.000010
# 49159611     0.000010
# 175429310    0.000010
# Name: patient_nbr, Length: 69668, dtype: float64
#
#
# Name of Feature: race
# Caucasian          0.764868
# AfricanAmerican    0.193079
# Hispanic           0.020474
# Other              0.015137
# Asian              0.006443
# Name: race, dtype: float64
#
#
# Name of Feature: gender
# Female             0.53848
# Male               0.46151
# Unknown/Invalid    0.00001
# Name: gender, dtype: float64
#
#
# Name of Feature: age
# [70-80)     0.255988
# [60-70)     0.221000
# [50-60)     0.169811
# [80-90)     0.168856
# [40-50)     0.095132
# [30-40)     0.037178
# [90-100)    0.027379
# [20-30)     0.016192
# [10-20)     0.006855
# [0-10)      0.001608
# Name: age, dtype: float64
#
#
# Name of Feature: admission_type_id
# 1    0.531696
# 3    0.186023
# 2    0.178766
# 6    0.052516
# 5    0.047511
# 8    0.003186
# 7    0.000201
# 4    0.000101
# Name: admission_type_id, dtype: float64
#
#
# Name of Feature: discharge_disposition_id
# 1     0.590675
# 3     0.136834
# 6     0.127627
# 18    0.036917
# 2     0.020715
# 22    0.019911
# 11    0.016162
# 5     0.011488
# 25    0.009780
# 4     0.007689
# 7     0.006141
# 23    0.004081
# 13    0.003990
# 14    0.003709
# 28    0.001387
# 8     0.001075
# 15    0.000633
# 24    0.000482
# 9     0.000211
# 17    0.000141
# 16    0.000111
# 19    0.000080
# 10    0.000060
# 27    0.000050
# 12    0.000030
# 20    0.000020
# Name: discharge_disposition_id, dtype: float64
#
#
# Name of Feature: admission_source_id
# 7     0.569206
# 1     0.290020
# 17    0.067321
# 4     0.030012
# 6     0.019991
# 2     0.010473
# 5     0.008523
# 3     0.001880
# 20    0.001608
# 9     0.000543
# 8     0.000161
# 22    0.000121
# 10    0.000070
# 14    0.000020
# 11    0.000020
# 25    0.000020
# 13    0.000010
# Name: admission_source_id, dtype: float64
#
#
# Name of Feature: time_in_hospital
# 3     0.174304
# 2     0.169268
# 1     0.139487
# 4     0.136743
# 5     0.098128
# 6     0.074035
# 7     0.057491
# 8     0.043189
# 9     0.029550
# 10    0.023027
# 11    0.018253
# 12    0.014343
# 13    0.011951
# 14    0.010232
# Name: time_in_hospital, dtype: float64
#
#
# Name of Feature: num_lab_procedures
# 1      0.031620
# 43     0.027640
# 44     0.024605
# 45     0.023399
# 38     0.021750
#          ...
# 121    0.000010
# 129    0.000010
# 120    0.000010
# 107    0.000010
# 118    0.000010
# Name: num_lab_procedures, Length: 118, dtype: float64
#
#
# Name of Feature: num_procedures
# 0    0.457319
# 1    0.204316
# 2    0.125516
# 3    0.093162
# 6    0.048496
# 4    0.041189
# 5    0.030002
# Name: num_procedures, dtype: float64
#
#
# Name of Feature: num_medications
# 13    0.059592
# 12    0.058959
# 11    0.056929
# 15    0.056909
# 14    0.056074
#         ...
# 70    0.000020
# 75    0.000020
# 81    0.000010
# 79    0.000010
# 74    0.000010
# Name: num_medications, Length: 75, dtype: float64
#
#
# Name of Feature: number_outpatient
# 0     0.834159
# 1     0.084519
# 2     0.035611
# 3     0.020313
# 4     0.010885
# 5     0.005277
# 6     0.003005
# 7     0.001558
# 8     0.000985
# 9     0.000834
# 10    0.000573
# 11    0.000412
# 13    0.000312
# 12    0.000302
# 14    0.000281
# 15    0.000201
# 16    0.000151
# 17    0.000080
# 21    0.000070
# 20    0.000070
# 18    0.000050
# 22    0.000050
# 19    0.000030
# 27    0.000030
# 24    0.000030
# 26    0.000020
# 23    0.000020
# 25    0.000020
# 33    0.000020
# 35    0.000020
# 36    0.000020
# 29    0.000020
# 34    0.000010
# 39    0.000010
# 42    0.000010
# 28    0.000010
# 37    0.000010
# 38    0.000010
# 40    0.000010
# Name: number_outpatient, dtype: float64
#
#
# Name of Feature: number_emergency
# 0     0.886394
# 1     0.076538
# 2     0.020373
# 3     0.007257
# 4     0.003759
# 5     0.001930
# 6     0.000945
# 7     0.000734
# 8     0.000503
# 10    0.000342
# 9     0.000332
# 11    0.000231
# 13    0.000121
# 12    0.000101
# 22    0.000060
# 16    0.000050
# 18    0.000050
# 19    0.000040
# 20    0.000040
# 15    0.000030
# 14    0.000030
# 25    0.000020
# 21    0.000020
# 28    0.000010
# 42    0.000010
# 46    0.000010
# 76    0.000010
# 37    0.000010
# 64    0.000010
# 63    0.000010
# 54    0.000010
# 24    0.000010
# 29    0.000010
# Name: number_emergency, dtype: float64
#
#
# Name of Feature: number_inpatient
# 0     0.661474
# 1     0.193159
# 2     0.075101
# 3     0.033912
# 4     0.016152
# 5     0.008111
# 6     0.004824
# 7     0.002694
# 8     0.001508
# 9     0.001116
# 10    0.000613
# 11    0.000492
# 12    0.000342
# 13    0.000201
# 14    0.000101
# 15    0.000090
# 16    0.000060
# 19    0.000020
# 17    0.000010
# 21    0.000010
# 18    0.000010
# Name: number_inpatient, dtype: float64
#
#
# Name of Feature: number_diagnoses
# 9     0.489421
# 5     0.107525
# 8     0.104932
# 7     0.102480
# 6     0.100560
# 4     0.054165
# 3     0.027811
# 2     0.009880
# 1     0.002151
# 16    0.000402
# 13    0.000161
# 10    0.000161
# 11    0.000111
# 12    0.000090
# 15    0.000080
# 14    0.000070
# Name: number_diagnoses, dtype: float64
#
#
# Name of Feature: max_glu_serum
# None    0.946830
# Norm    0.025841
# >200    0.014735
# >300    0.012594
# Name: max_glu_serum, dtype: float64
#
#
# Name of Feature: A1Cresult
# None    0.833194
# >8      0.080016
# Norm    0.049300
# >7      0.037490
# Name: A1Cresult, dtype: float64
#
#
# Name of Feature: metformin
# No        0.803795
# Steady    0.180113
# Up        0.010443
# Down      0.005649
# Name: metformin, dtype: float64
#
#
# Name of Feature: repaglinide
# No        0.984632
# Steady    0.013820
# Up        0.001096
# Down      0.000452
# Name: repaglinide, dtype: float64
#
#
# Name of Feature: nateglinide
# No        0.993005
# Steady    0.006654
# Up        0.000231
# Down      0.000111
# Name: nateglinide, dtype: float64
#
#
# Name of Feature: chlorpropamide
# No        0.999146
# Steady    0.000784
# Up        0.000060
# Down      0.000010
# Name: chlorpropamide, dtype: float64
#
#
# Name of Feature: glimepiride
# No        0.949403
# Steady    0.045501
# Up        0.003226
# Down      0.001869
# Name: glimepiride, dtype: float64
#
#
# Name of Feature: acetohexamide
# No        0.99999
# Steady    0.00001
# Name: acetohexamide, dtype: float64
#
#
# Name of Feature: glipizide
# No        0.875368
# Steady    0.111586
# Up        0.007578
# Down      0.005468
# Name: glipizide, dtype: float64
#
#
# Name of Feature: glyburide
# No        0.895681
# Steady    0.090851
# Up        0.007980
# Down      0.005488
# Name: glyburide, dtype: float64
#
#
# Name of Feature: tolbutamide
# No        0.999779
# Steady    0.000221
# Name: tolbutamide, dtype: float64
#
#
# Name of Feature: pioglitazone
# No        0.927864
# Steady    0.068648
# Up        0.002312
# Down      0.001176
# Name: pioglitazone, dtype: float64
#
#
# Name of Feature: rosiglitazone
# No        0.937413
# Steady    0.059984
# Up        0.001759
# Down      0.000844
# Name: rosiglitazone, dtype: float64
#
#
# Name of Feature: acarbose
# No        0.996965
# Steady    0.002905
# Up        0.000101
# Down      0.000030
# Name: acarbose, dtype: float64
#
#
# Name of Feature: miglitol
# No        0.999618
# Steady    0.000312
# Down      0.000050
# Up        0.000020
# Name: miglitol, dtype: float64
#
#
# Name of Feature: troglitazone
# No        0.99997
# Steady    0.00003
# Name: troglitazone, dtype: float64
#
#
# Name of Feature: tolazamide
# No        0.999608
# Steady    0.000382
# Up        0.000010
# Name: tolazamide, dtype: float64
#
#
# Name of Feature: insulin
# No        0.467329
# Steady    0.300544
# Down      0.121003
# Up        0.111123
# Name: insulin, dtype: float64
#
#
# Name of Feature: glyburide-metformin
# No        0.993165
# Steady    0.006744
# Up        0.000060
# Down      0.000030
# Name: glyburide-metformin, dtype: float64
#
#
# Name of Feature: glipizide-metformin
# No        0.999869
# Steady    0.000131
# Name: glipizide-metformin, dtype: float64
#
#
# Name of Feature: glimepiride-pioglitazone
# No        0.99999
# Steady    0.00001
# Name: glimepiride-pioglitazone, dtype: float64
#
#
# Name of Feature: metformin-rosiglitazone
# No    1.0
# Name: metformin-rosiglitazone, dtype: float64
#
#
# Name of Feature: metformin-pioglitazone
# No        0.99999
# Steady    0.00001
# Name: metformin-pioglitazone, dtype: float64
#
#
# Name of Feature: change
# No    0.53855
# Ch    0.46145
# Name: change, dtype: float64
#
#
# Name of Feature: diabetesMed
# Yes    0.768818
# No     0.231182
# Name: diabetesMed, dtype: float64
#
#
# Name of Feature: readmitted
# NO     0.535887
# >30    0.351854
# <30    0.112259
# Name: readmitted, dtype: float64

# %%
# Creating the key univariate plots on features
# create_plot function accepts the following parameters and generates a specific type of plot
#(xAxis-Data, yAxis-Data, xAxis-Label,yAxis-Label,Title of Plot, Plot type, Override default figsize)

# Create a number of Boxplots
create_plots('A1Cresult','time_in_hospital','A1C Result','Length of Stay in Days','Result of >7 or >8 Indicates High Levels of Blood Glucose Over The Past Three Months','Boxplot')

create_plots('max_glu_serum','time_in_hospital','Blood Glucose Level','Length of Stay in Days','Glucose Serum of >200 or >300 Is High Health Risk','Boxplot')

# Create a number of Barplots
create_plots('readmitted','patient_nbr','Types of Readmission','Counts','Count of Readmissions: <30 Days, >=30 Days, No Readmission','Barplot')

create_plots('diabetesMed','patient_nbr','On Diabetes Medication','Counts','Count on Diabetes Medications','Barplot')

create_plots('age','patient_nbr','Age Brackets','Counts','Count in Age Brackets','Barplot',10)

create_plots('gender','patient_nbr','Gender','Counts','Count by Gender','Barplot')

create_plots('race','patient_nbr','Race','Counts','Count by Race','Barplot')

# Create a number of Histplots
histplot_features_list = ['num_lab_procedures', 'num_procedures',\
    'num_medications','number_outpatient','number_emergency','number_inpatient','number_diagnoses']

for plot in histplot_features_list:
    plotLbl = plot.replace("_"," ")
    plotLbl = plotLbl.title()
    create_plots(plot,'blank',plotLbl,'Counts','Distribution of ' + plotLbl,'Histplot')

# Create Heatmap to show correlation
create_plots('Features with Numeric Values','Features with Numeric Values','Features with Numeric Values','Features with Numeric Values','Heatmap Showing Correlation Between Numeric Features','Heatmap',10)

# %% [markdown]
# <h1>Start of Citation and References Section</h1>

# %% [markdown]
# 1) Source of data is UCI Machine Learning Repository, URL is: https://archive.ics.uci.edu/ml/datasets/Diabetes+130-US+hospitals+for+years+1999-2008

# %% [markdown]
# 2) The data is submitted on provided the Virigina Commonwealth University, on Diabetes related admission on 130-US hospitals for years 1999 to 2008.

# %% [markdown]
# 3) Target is predicting classifying admissions as re-admit; less than 30, more than 30 or none.

# %% [markdown]
# 4) This is a classification problem

# %% [markdown]
# 5) Data has 55 features and 6) 100,000 rows of data

# %% [markdown]
# 7) Dataset is has a lot of rows, it is going to test my healthcare background. One of the reasons why I choose this data, I have done a lot of work on clinical outcomes.

# %% [markdown]
# Additional Sources and Citations:
# 1. List of features and descriptions: https://www.hindawi.com/journals/bmri/2014/781670/tab1/
# 2. Open Access article: https://www.hindawi.com/journals/bmri/2014/781670/
# 3. Citation: Beata Strack, Jonathan P. DeShazo, Chris Gennings, Juan L. Olmo, Sebastian Ventura, Krzysztof J. Cios, John N. Clore, "Impact of HbA1c Measurement on Hospital Readmission Rates: Analysis of 70,000 Clinical Database Patient Records", BioMed Research International, vol. 2014, Article ID 781670, 11 pages, 2014. https://doi.org/10.1155/2014/781670
